# %%
from vae import VAE
from data import DataLoader

# %%
# parameters for training
epochs = 100
learning_rate = 1e-4
batch_size = 32
hidden_sizes = [250, 100]
latent_size = 2

# %%
# initializing the data loader
data_loader = DataLoader(batch_size=batch_size)

# initializing the variational autoencoder
vae = VAE(hidden_sizes=hidden_sizes, latent_size=latent_size)

# %%
# training
vae.train(data_loader, epochs, learning_rate)

# %%
# visualizing the latent space for training data
vae.visualize_latent_space(data_loader.data, data_loader.labels)

# %%
# visualizing the decoder output manifold for a square grid in latent space
vae.visualize_manifold()
